# %%
import time
import pandas as pd
import random

# --- PART 1: SALES FORECAST LOGIC ---
# This section simulates the data processing task.

print("--- Starting Sales Forecast Pipeline ---")

# 1. Simulate Data Loading
print("[INFO] Loading historical sales data...")
# Simulating a delay to mimic heavy processing
time.sleep(1) 

# Create dummy data (Simulating a database fetch)
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May'],
    'Sales': [random.randint(1000, 5000) for _ in range(5)]
}
df = pd.DataFrame(data)

# 2. Perform "Forecasting"
print("[INFO] Running forecast algorithm...")
# Simple logic: predicting 10% growth
df['Forecast'] = df['Sales'] * 1.1 

# 3. Display Results
print("[INFO] Forecast generated successfully:")
print(df)

print("--- Pipeline Finished Successfully ---")
# Out:
# --- Starting Sales Forecast Pipeline ---
# [INFO] Loading historical sales data...
# [INFO] Running forecast algorithm...
# [INFO] Forecast generated successfully:
#   Month  Sales  Forecast
# 0   Jan   3789    4167.9
# 1   Feb   3681    4049.1
# 2   Mar   4872    5359.2
# 3   Apr   2121    2333.1
# 4   May   1804    1984.4
# --- Pipeline Finished Successfully ---

# %%
import os

# --- PART 2: AUTOMATION SETUP (Infrastructure as Code) ---
# This script creates the GitHub Actions configuration file.

def create_github_workflow():
    # 1. Define the directory structure required by GitHub
    workflow_dir = ".github/workflows"
    
    # Check if directory exists, if not, create it
    if not os.path.exists(workflow_dir):
        os.makedirs(workflow_dir)
        print(f"[SETUP] Created directory: {workflow_dir}")
    else:
        print(f"[SETUP] Directory '{workflow_dir}' already exists.")

    # 2. Define the YAML Content
    # SECURITY NOTE: We use ${{ secrets.TARGET_EMAIL }} instead of a real email.
    yaml_content = """name: Secure Sales Forecast Pipeline

# Trigger: Runs on every push to the 'main' branch
on:
  push:
    branches: [ "main" ]
  workflow_dispatch:

jobs:
  run-secure-forecast:
    runs-on: ubuntu-latest
    
    steps:
      # Step 1: Checkout the code
      - name: Checkout Code
        uses: actions/checkout@v3

      # Step 2: Setup Python
      - name: Set up Python
        uses: actions/setup-python@v4
        with:
          python-version: '3.9'
      - name: Debug Secret
          run: |
          echo "Mengecek apakah email ada..."
              if [ -z "${{ secrets.TARGET_EMAIL }}" ]; then
                echo "GAWAT! Secret TARGET_EMAIL kosong atau tidak terbaca."
                exit 1
              else
                echo "Bagus! Secret terdeteksi (GitHub akan menyensornya jadi ***)."
              fi
          
      # Step 3: Install Dependencies (including sendmail)
      - name: Install Libraries
        run: |
        
          sudo apt-get update && sudo apt-get install -y sendmail
          pip install papermill jupyter ipykernel pandas

      # Step 4: Execute the Notebook using Papermill
      - name: Execute Forecasting Notebook
        id: run_notebook
        run: |
          papermill SalesForecastPipeline.ipynb Output_Report.ipynb

      # Step 5: Error Notification (Runs ONLY on failure)
      - name: Notify Failure (Secure)
        if: failure()
        run: |
          echo "Subject: WORKFLOW FAILED - Sales Pipeline" | sendmail -v ${{ secrets.TARGET_EMAIL }}
          echo "The pipeline failed. Please check the logs." | sendmail -v ${{ secrets.TARGET_EMAIL }}

      # Step 6: Success Notification (Runs ONLY on success)
      - name: Notify Success (Secure)
        if: success()
        run: |
          echo "Subject: SUCCESS - Sales Forecast Ready" | sendmail -v ${{ secrets.TARGET_EMAIL }}
          echo "The sales forecast was generated successfully." | sendmail -v ${{ secrets.TARGET_EMAIL }}
"""

    # 3. Write the file to the disk
    file_path = os.path.join(workflow_dir, "automation_task.yml")
    with open(file_path, "w") as f:
        f.write(yaml_content)
    
    print(f"[SUCCESS] Automation configuration saved to: {file_path}")
    print("[NEXT STEP] Please follow the instructions below to configure your Secrets.")

if __name__ == "__main__":
    create_github_workflow()
# Out:
# [SETUP] Created directory: .github/workflows
# [SUCCESS] Automation configuration saved to: .github/workflows\automation_task.yml
# [NEXT STEP] Please follow the instructions below to configure your Secrets.

# %%
# --- PART 3: SECURE GIT SETUP (HIDDEN INPUT) ---
import os
import getpass  # Library khusus untuk menyembunyikan input

print("--- 1. Installing Required Libraries ---")
# !pip install papermill pandas jupyter

print("\n--- 2. Interactive Git Setup ---")
print("To keep this file secure, please enter your details below.")
print("The characters you type will be HIDDEN (like a password field).")

# Menggunakan getpass.getpass() agar teks yang diketik tidak muncul di layar
# strip() tetap digunakan untuk membersihkan spasi
try:
    git_email = getpass.getpass("Enter your Git Email: ").strip()
    git_name = getpass.getpass("Enter your Git Name: ").strip()
except Exception as e:
    print("Error handling input. Please try again.")
    git_email = None
    git_name = None

if git_email and git_name:
    # Configure Git locally using the hidden variables
    # !git config user.email "{git_email}"
    # !git config user.name "{git_name}"
    
    # Initialize and Commit
    # !git init
    # !git add .
    # !git commit -m "Auto-commit from Jupyter Tutorial"
    
    print(f"\n[SUCCESS] Git configured locally.")
    
else:
    print("\n[SKIPPED] Input was empty. Setup skipped.")

print("-" * 50)
print("⚠️ FINAL MANUAL STEP ⚠️")
print("To push this to GitHub securely, copy and run these commands in your Terminal:")
print("\n1. Link Repo: git remote add origin https://github.com/YOUR_USERNAME/YOUR_REPO.git")
print("2. Push Code: git push -u origin main")
# Out:
# --- 1. Installing Required Libraries ---
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: papermill in d:\anaconda\envs\kerja\lib\site-packages (2.6.0)
# Requirement already satisfied: pandas in d:\anaconda\envs\kerja\lib\site-packages (2.3.3)
# Requirement already satisfied: jupyter in d:\anaconda\envs\kerja\lib\site-packages (1.1.1)
# Requirement already satisfied: click in c:\users\rog\appdata\roaming\python\python311\site-packages (from papermill) (8.2.1)
# Requirement already satisfied: pyyaml in c:\users\rog\appdata\roaming\python\python311\site-packages (from papermill) (6.0.2)
# Requirement already satisfied: nbformat>=5.2.0 in d:\anaconda\envs\kerja\lib\site-packages (from papermill) (5.10.4)
# Requirement already satisfied: nbclient>=0.2.0 in d:\anaconda\envs\kerja\lib\site-packages (from papermill) (0.10.2)
# Requirement already satisfied: tqdm>=4.32.2 in c:\users\rog\appdata\roaming\python\python311\site-packages (from papermill) (4.67.1)
# Requirement already satisfied: requests in c:\users\rog\appdata\roaming\python\python311\site-packages (from papermill) (2.32.4)
# Requirement already satisfied: entrypoints in d:\anaconda\envs\kerja\lib\site-packages (from papermill) (0.4)
# Requirement already satisfied: tenacity>=5.0.2 in c:\users\rog\appdata\roaming\python\python311\site-packages (from papermill) (9.1.2)
# Requirement already satisfied: ansicolors in d:\anaconda\envs\kerja\lib\site-packages (from papermill) (1.1.8)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\rog\appdata\roaming\python\python311\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rog\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rog\appdata\roaming\python\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rog\appdata\roaming\python\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: notebook in d:\anaconda\envs\kerja\lib\site-packages (from jupyter) (7.5.0)
# Requirement already satisfied: jupyter-console in d:\anaconda\envs\kerja\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in d:\anaconda\envs\kerja\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in d:\anaconda\envs\kerja\lib\site-packages (from jupyter) (7.1.0)
# Requirement already satisfied: ipywidgets in d:\anaconda\envs\kerja\lib\site-packages (from jupyter) (8.1.8)
# Requirement already satisfied: jupyterlab in d:\anaconda\envs\kerja\lib\site-packages (from jupyter) (4.5.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\anaconda\envs\kerja\lib\site-packages (from nbclient>=0.2.0->papermill) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\anaconda\envs\kerja\lib\site-packages (from nbclient>=0.2.0->papermill) (5.9.1)
# Requirement already satisfied: traitlets>=5.4 in d:\anaconda\envs\kerja\lib\site-packages (from nbclient>=0.2.0->papermill) (5.14.3)
# Requirement already satisfied: pyzmq>=23.0 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.2.0->papermill) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.2.0->papermill) (6.5.2)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbclient>=0.2.0->papermill) (4.5.0)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\anaconda\envs\kerja\lib\site-packages (from nbformat>=5.2.0->papermill) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in d:\anaconda\envs\kerja\lib\site-packages (from nbformat>=5.2.0->papermill) (4.25.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\rog\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->papermill) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda\envs\kerja\lib\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->papermill) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda\envs\kerja\lib\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->papermill) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda\envs\kerja\lib\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->papermill) (0.29.0)
# Requirement already satisfied: six>=1.5 in c:\users\rog\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\rog\appdata\roaming\python\python311\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat>=5.2.0->papermill) (4.14.0)
# Requirement already satisfied: colorama in c:\users\rog\appdata\roaming\python\python311\site-packages (from tqdm>=4.32.2->papermill) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda\envs\kerja\lib\site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in d:\anaconda\envs\kerja\lib\site-packages (from ipykernel->jupyter) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in d:\anaconda\envs\kerja\lib\site-packages (from ipykernel->jupyter) (9.7.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\anaconda\envs\kerja\lib\site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in d:\anaconda\envs\kerja\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\rog\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter) (25.0)
# Requirement already satisfied: psutil>=5.7 in d:\anaconda\envs\kerja\lib\site-packages (from ipykernel->jupyter) (7.1.3)
# Requirement already satisfied: decorator>=4.3.2 in d:\anaconda\envs\kerja\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in d:\anaconda\envs\kerja\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in d:\anaconda\envs\kerja\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\anaconda\envs\kerja\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\rog\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.19.1)
# Requirement already satisfied: stack_data>=0.6.0 in d:\anaconda\envs\kerja\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: wcwidth in d:\anaconda\envs\kerja\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\anaconda\envs\kerja\lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel->jupyter) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in d:\anaconda\envs\kerja\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\anaconda\envs\kerja\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (3.0.1)
# Requirement already satisfied: pure-eval in d:\anaconda\envs\kerja\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in d:\anaconda\envs\kerja\lib\site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in d:\anaconda\envs\kerja\lib\site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in d:\anaconda\envs\kerja\lib\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\rog\appdata\roaming\python\python311\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\rog\appdata\roaming\python\python311\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\anaconda\envs\kerja\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\anaconda\envs\kerja\lib\site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in d:\anaconda\envs\kerja\lib\site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in d:\anaconda\envs\kerja\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\rog\appdata\roaming\python\python311\site-packages (from jupyterlab->jupyter) (80.9.0)
# Requirement already satisfied: anyio in c:\users\rog\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.9.0)
# Requirement already satisfied: certifi in c:\users\rog\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\rog\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\users\rog\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\rog\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\rog\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.9.0)
# Requirement already satisfied: babel>=2.10 in d:\anaconda\envs\kerja\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in d:\anaconda\envs\kerja\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\rog\appdata\roaming\python\python311\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda\envs\kerja\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rog\appdata\roaming\python\python311\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.0.0)
# Requirement already satisfied: rfc3339-validator in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\anaconda\envs\kerja\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in d:\anaconda\envs\kerja\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in d:\anaconda\envs\kerja\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\anaconda\envs\kerja\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in d:\anaconda\envs\kerja\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in d:\anaconda\envs\kerja\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in d:\anaconda\envs\kerja\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\envs\kerja\lib\site-packages (from nbconvert->jupyter) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in d:\anaconda\envs\kerja\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.3.0)
# Requirement already satisfied: defusedxml in d:\anaconda\envs\kerja\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda\envs\kerja\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\anaconda\envs\kerja\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda\envs\kerja\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in d:\anaconda\envs\kerja\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in d:\anaconda\envs\kerja\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rog\appdata\roaming\python\python311\site-packages (from requests->papermill) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rog\appdata\roaming\python\python311\site-packages (from requests->papermill) (2.4.0)
# Requirement already satisfied: lark>=1.2.2 in d:\anaconda\envs\kerja\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\rog\appdata\roaming\python\python311\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\rog\appdata\roaming\python\python311\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\envs\kerja\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in d:\anaconda\envs\kerja\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.4.0)
#
# --- 2. Interactive Git Setup ---
# To keep this file secure, please enter your details below.
# The characters you type will be HIDDEN (like a password field).
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Enter your Git Email:  ········
# Enter your Git Name:  ········
# Reinitialized existing Git repository in D:/SrotTest/Task3/.git/
# warning: in the working copy of '.ipynb_checkpoints/WorkflowSegmentation-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'WorkflowSegmentation.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main 5076628] Auto-commit from Jupyter Tutorial
#  13 files changed, 688 insertions(+), 1583 deletions(-)
#  create mode 100644 .github/workflows/automation_task.yml
#  delete mode 100644 papermill - workflow automation/project 1 salesforecastpipeline/.ipynb_checkpoints/SalesForecastPipeline-checkpoint.ipynb
#  delete mode 100644 papermill - workflow automation/project 1 salesforecastpipeline/.ipynb_checkpoints/TheAutomation-checkpoint.ipynb
#  delete mode 100644 papermill - workflow automation/project 1 salesforecastpipeline/SalesForecastPipeline.ipynb
#  delete mode 100644 papermill - workflow automation/project 1 salesforecastpipeline/TheAutomation.ipynb
#  delete mode 100644 papermill - workflow automation/project 1 salesforecastpipeline/output_notebooks/.ipynb_checkpoints/SalesForecastPipeline_Feb-checkpoint.ipynb
#  delete mode 100644 papermill - workflow automation/project 1 salesforecastpipeline/output_notebooks/.ipynb_checkpoints/SalesForecastPipeline_Jan-checkpoint.ipynb
#  delete mode 100644 papermill - workflow automation/project 1 salesforecastpipeline/output_notebooks/.ipynb_checkpoints/SalesForecastPipeline_Mar-checkpoint.ipynb
#  delete mode 100644 papermill - workflow automation/project 1 salesforecastpipeline/output_notebooks/SalesForecastPipeline_Feb.ipynb
#  delete mode 100644 papermill - workflow automation/project 1 salesforecastpipeline/output_notebooks/SalesForecastPipeline_Jan.ipynb
#  delete mode 100644 papermill - workflow automation/project 1 salesforecastpipeline/output_notebooks/SalesForecastPipeline_Mar.ipynb
#
# [SUCCESS] Git configured locally.
# --------------------------------------------------
# ⚠️ FINAL MANUAL STEP ⚠️
# To push this to GitHub securely, copy and run these commands in your Terminal:
#
# 1. Link Repo: git remote add origin https://github.com/YOUR_USERNAME/YOUR_REPO.git
# 2. Push Code: git push -u origin main

# %%
# --- STEP 4: CONNECT TO REPO (HIDDEN & ROBUST) ---
import getpass
import subprocess

print("--- Connect to GitHub Repository ---")
print("Paste your Repository URL below.")
print("It will be HIDDEN (no text will appear).")

try:
    # 1. Capture URL securely
    repo_url = getpass.getpass("Paste Repo URL: ").strip()
except:
    repo_url = None

if repo_url:
    # 2. Remove old connection if exists (Silent Mode)
    subprocess.run(["git", "remote", "remove", "origin"], stderr=subprocess.DEVNULL)
    
    # 3. Add new connection (The Injection)
    result = subprocess.run(["git", "remote", "add", "origin", repo_url], capture_output=True, text=True)
    
    if result.returncode == 0:
        print("\n[SUCCESS] ✅ Repository connected successfully!")
        print("Your URL is saved securely in the background.")
        print("-" * 50)
        print("⚠️ FINAL STEP (TERMINAL) ⚠️")
        print("Open your Terminal (Split Screen) and run ONLY this command:")
        print("\n   git push -u origin main")
    else:
        print(f"\n[ERROR] Could not connect. Ensure URL is correct.")
else:
    print("\n[ABORTED] URL cannot be empty.")
# Out:
# --- Connect to GitHub Repository ---
# Paste your Repository URL below.
# It will be HIDDEN (no text will appear).
# Paste Repo URL:  ········
# [SUCCESS] ✅ Repository connected successfully!
# Your URL is saved securely in the background.
# --------------------------------------------------
# ⚠️ FINAL STEP (TERMINAL) ⚠️
# Open your Terminal (Split Screen) and run ONLY this command:
#
#    git push -u origin main
